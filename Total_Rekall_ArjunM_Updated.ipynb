# %%
# Name: Arjun Manohar
# Project: Text Adventure Game
# Date: 02-12-2022
# Version: 2.0

# importing the necessary packages
import time
import random


# Introduction to the game
def intro():
    
    # Docstring
    """ One Way Out is a self-written fictional story. It's what happens when you
    take one famous movie; Total Recall, and an equally famous (debatable) hit 
    sitcom; Castle, and combine them. 
    
    You are either Douglas Quaid or Karl Hauser. One is an average Joe and the other is
    a special forces veteran. For anyone unfamiliar with the movie, Total Recall 
    is set in the future and Rekall is a company that implants artificial memories
    for those looking to escape the mundane responsibilities of their life. 
    
    In this game you start within Douglas's/Karl's dream and, you are the protagonist
    and it's your job to get out of this labyrinth of rooms, all the while trying 
    to remember who you are or how you got here. 
    
    You win, when you escape from your captors and exit the dream.
    """

    print(f"""     

    WELCOME TO ONE WAY OUT
    {'*' * 80}

       ____  _   ________   _       _______  __   ____  __  ________
      / __ \/ | / / ____/  | |     / /   \ \/ /  / __ \/ / / /_  __/
     / / / /  |/ / __/     | | /| / / /| |\  /  / / / / / / / / /   
    / /_/ / /|  / /___     | |/ |/ / ___ |/ /  / /_/ / /_/ / / /    
    \____/_/ |_/_____/     |__/|__/_/  |_/_/   \____/\____/ /_/     


    {'*' * 80}

    Introduction:

    You wake up unconscious in a dark apartment. You are experiencing headaches and
    worst of all you cannot seem to recollect anything about the last 24 hours. All
    that matters now is how you plan on getting out of here. 

    {'*' * 80}

    """)

# Building the game
def scene1():
    
    # All scenes in this game are formatted as code chunk
    # They will mirror each other in terms of format and functionality
    # All scene related loop will also have the same variables albeit with 
    # a minor exception. The scene number will update to reflect the current scene
    
    print(f"""
            Your head feels heavy, yet you try getting up but you notice that 
            your hands feel cold and tied together. You feel handcuffed, but its
            difficult to be sure since the room is so dark. You walk around and
            get a feel of the room. You spot a curtain and a door. Now, you got
            two options: 
            
            Type your choice: Open curtains or Open door
 
            """)
    
    # The following option "Choose" will randomly select one of the two 
    # available options for the user
    
    {time.sleep(2)}
    print("""   
            If you can't decide enter "Choose" and we will choose for you :)
            
            """) 
    
    scene1_choice = input(prompt = """> """).upper() # Taking the user I/P
    scene1_answer = []                       # Dummy list to store each word of the I/P
    scene1_answer = scene1_choice.split(" ") # Spliting the user I/P into words
    
    # Choice Control Logic
    # The user is not confined to any specific type of input and their responses
    # will be gathered and split into individual words then saved to an empty list
    # Then using conditional statements we will check if the desired word is within
    # list of words the user inputted
    
    if('CURTAINS' in scene1_answer or 'CURTAIN' in scene1_answer):
        scene1_2()
    
    elif('DOOR' in scene1_answer or 'DOORS' in scene1_answer):
        scene1_1()
    
    # The following condition will invoke the random logic explained in lines 74 & 75
    
    elif('CHOSE' in scene1_answer or 'CHOOSE' in scene1_answer or 'CHOICE' in scene1_answer):
        
        rand_choices1 = ['DOOR', 'CURTAIN']      # setting choices to the available options
        rand_ans1 = random.choice(rand_choices1) # selecting a choice at random
    
        if(rand_ans1 == 'DOOR'):
            print(f"We picked {rand_ans1.lower()} for you!")
            time.sleep(2)
            scene1_1()
        
        else:
            print(f"We picked {rand_ans1.lower()} for you!")
            time.sleep(2)
            scene1_2()
            
    else:
        print("Incorrect input!\n")
        scene_no = 1 # Passing the scene number to the error loop to return back here
        ask_user(scene_no) # Calling the error loop

        
def scene1_1():
    print(f"""
            You strain to grasp the door doorknob since you are shackled. In 
            addition, the metal handcuffs bang against the door, drawing 
            attention to yourself. You hear footsteps marching directly towards 
            you, but it's too late. A masked man enters the room and knocks 
            you unconscious and says,
 
            """)
    
    time.sleep(2) # Time sleep function is used to control the pace of gameplay
    
    # Letter by Letter Logic
    # The following loop is designed dramatic effect wherein the statement is printed
    # out one letter at a time
    # This logic will be repeated throughout the code 
    
    scene1_1phrase ="""\t\t\t You're never getting out of here! """
    for character in scene1_1phrase:
        print(character, end ="")
        time.sleep(0.05)
    
    time.sleep(5)
    game_over()


def scene1_2():
    print(f"""
            Examining the room is a wise decision. You try to open the drapes 
            while still in handcuffs. You are able to pull just enough to let 
            a ray of sunlight into the room. You notice a pair of keys and 
            a map on the dresser as the room brightens. You use the keys to 
            break free from the handcuffs, but now you're faced with a decision.
            
            Either use the same keys to open the door or read the map
            
            Type your choice: Read map or Open door
 
            """)
    
    # The following option "Choose" will randomly select one of the two 
    # available options for the user
    
    {time.sleep(2)}
    print("""   
            Can't decide still? Enter "Choose" and we will select for you :)
            
            """) 
    
    #Choice Control Logic
    
    scene1_2choice = input(prompt = """> """).upper() # Taking the user I/P
    scene1_2answer = []                       # Dummy list to store each word of the I/P
    scene1_2answer = scene1_2choice.split(" ") # Spliting the user I/P into words
    
    if('READ' in scene1_2answer or 'MAP' in scene1_2answer or 'MAPS' in scene1_2answer):
        scene2()
    
    elif('DOOR' in scene1_2answer or 'DOORS' in scene1_2answer):
        print(f"""
            You try lockpicking the door with keys to no avail. You scream in 
            frustration, only to draw more attention towards yourself! Suddenly
            you hear footsteps marching right towards you. A masked man enters the 
            room and knocks you unconscious and says,
            
            "We're not finished with you yet...so sit down and shut up!"
        
            """)
        
        time.sleep(5)
        game_over() # Calling Failure loop 
    
    # The following condition will invoke the random logic 
    
    elif('CHOSE' in scene1_2answer or 'CHOOSE' in scene1_2answer or 'CHOICE' in scene1_2answer or 'SELECT' in scene1_2answer):
        
        rand_choices2 = ['DOOR', 'MAP']          # setting choices to the available options
        rand_ans2 = random.choice(rand_choices2) # selecting a choice at random
    
        if(rand_ans2 == 'MAP'):
            print(f"We picked {rand_ans2.lower()} for you!")
            time.sleep(2)
            scene2()
        
        else:
            print(f"We picked {rand_ans2.lower()} for you!")
            time.sleep(2)
            print(f"""
            
            You try lockpicking the door with keys to no avail. You scream in 
            frustration, only to draw more attention towards yourself! Suddenly
            you hear footsteps marching right towards you. A masked man enters the 
            room and knocks you unconscious and says,
            
            "We're not finished with you yet...so sit down and shut up!"
        
            """)
        
            time.sleep(5)
            game_over() # Calling Failure loop 
            
    else:
        print("Incorrect input!\n")
        scene_no = 1.2 # Passing the scene number to the error loop to return back here
        ask_user(scene_no) # The Error loop

        
def scene2():
    print(f"""
            The maps reveals a service latch behind the dresser. Using the keys
            as a screwdriver you unfasten the screws holding the latch. Upon opening
            the latch you find a passage way and in it a bag. You open the bag to
            find two passports, a keys to a Range Rover and a note with a 
            phone number. But before you could delve any deeper, you hear 
            footsteps approaching your room. 
            
            You grab onto the bag but need to move quickly. The maps reveal 
            two possible options.
            
            You can either head to the maintenance room and look for a phone or you
            can head down the shaft to the garage and possibly drive out of here. 
            Where will you go?
            
            Type your choice: Maintenance room or Garage
 
            """)
    
    # The following option "Choose" will randomly select one of the two 
    # available options for the user
    
    {time.sleep(2)}
    print("""   
            Okay, this is a tough one! Enter "Choose" and we will decide for you :)
            
            """) 
    
    #Choice Control Logic - Explained in scene_1
    
    scene2_choice = input(prompt = """> """).upper() # Taking the user I/P
    scene2_answer = []                       # Dummy list to store each word of the I/P
    scene2_answer = scene2_choice.split(" ") # Spliting the user I/P into words
    
    if('GARAGE' in scene2_answer or 'GARASH' in scene2_answer):
        scene3()
    
    elif('MAINTENANCE' in scene2_answer or 'ROOM' in scene2_answer):
        print(f"""
            As you make your way down the shaft and into the maintenance room, 
            you slip and fall. Hearing this commotion, a guard bursts into the 
            room and pulls out a tazer! You get stunned just as you were trying 
            to reach for the phone. You become unconscious and pass out. 
            
            You wake up only to find yourself back where you started. In the room.
            
            """)
        time.sleep(5)
        game_over() # Calling Failure loop 
    
    # The following condition will invoke the random logic 
    
    elif('CHOSE' in scene2_answer or 'CHOOSE' in scene2_answer or 'CHOICE' in scene2_answer or 'DECIDE' in scene2_answer):
        
        rand_choices3 = ['GARAGE', 'MAINTENANCE']  # setting choices to the available options
        rand_ans3 = random.choice(rand_choices3)   # selecting a choice at random
    
        if(rand_ans3 == 'GARAGE'):
            print(f"We picked {rand_ans3.lower()} for you!")
            time.sleep(2)
            scene3()
        
        else:
            print(f"We picked {rand_ans3.lower()} for you!")
            time.sleep(2)
            print(f"""
            As you make your way down the shaft and into the maintenance room, 
            you slip and fall. Hearing this commotion, a guard bursts into the 
            room and pulls out a tazer! You get stunned just as you were trying 
            to reach for the phone. You become unconscious and pass out. 
            
            You wake up only to find yourself back where you started. In the room.
            
            """)
        time.sleep(5)
        game_over() # Calling Failure loop
            
            
    else:
        print("Incorrect input! Check your spelling perhaps?\n")
        scene_no = 2 # Passing the scene number to the error loop to return back here
        ask_user(scene_no) # The Error loop
    
        
def scene3():
    print(f"""
            You made it to the garage. You can almost taste the freedom. You get
            into a parked Range Rover and you race out of the garage. Nothing looks
            familiar to you, and worst yet, this doesn't even feel like the same country.
            The road is flanked by large deserts on both sides. You are driving 
            as fast as you can, but where do you go? Coincidentally, you reach a
            mile marker that reads "Downtown Dubai 5 miles". 
            
            Dubai? How did you end up here? Nevertheless you got only two options,
            you can either head to the police station or your country's consulate.
            
            Type your choice: Police Station or Consulate
 
            """)
    
    # The following option "Choose" will randomly select one of the two 
    # available options for the user
    
    {time.sleep(2)}
    print("""   
            If you can't decide enter "Choose" and we will pick for you :)
            
            """) 
    
    #Choice Control Logic - Explained in scene_1
    
    scene3_choice = input(prompt = """> """).upper() # Taking the user I/P
    scene3_answer = []                       # Dummy list to store each word of the I/P
    scene3_answer = scene3_choice.split(" ") # Spliting the user I/P into words
    
    if('POLICE' in scene3_answer or 'STATION' in scene3_answer):
        print(f"""
            Before you could make it to the police station, you are intercepted by
            a group of masked men. You try to run but they have you surrounded.
            Feeling tired, you surrender and take hold you down and inject you
            with something and you become unconscious.
            
            You wake up only to find yourself back where you started. In the room.
            
            """)
        
        time.sleep(5)
        game_over() # Calling Failure loop 
        
    
    elif('CONSULATE' in scene3_answer or 'COUNSULATE' in scene3_answer):
        scene4()
    
    # The following condition will invoke a random logic
    
    elif('CHOSE' in scene3_answer or 'CHOOSE' in scene3_answer or 'CHOICE' in scene3_answer or 'PICK' in scene3_answer):
        
        rand_choices4 = ['CONSULATE', 'POLICE']     # setting choices to the available options
        rand_ans4 = random.choice(rand_choices4) # selecting a choice at random
    
        if(rand_ans4 == 'CONSULATE'):
            print(f"We picked {rand_ans4.lower()} for you!")
            time.sleep(2)
            scene4()
        
        else:
            print(f"We picked {rand_ans4.lower()} for you!")
            time.sleep(2)
            print(f"""
            Before you could make it to the police station, you are intercepted by
            a group of masked men. You try to run but they have you surrounded.
            Feeling tired, you surrender and take hold you down and inject you
            with something and you become unconscious.
            
            You wake up only to find yourself back where you started. In the room.
            
            """)
        
        time.sleep(5)
        game_over() # Calling Failure loop 
            
    else:
        print("Incorrect input! Check your spelling perhaps?\n")
        scene_no = 3 # Passing the scene number to the error loop to return back here
        ask_user(scene_no) # The Error loop
        
def scene4():
    print(f"""
            You are at the Dubai Embassy District, a district that houses consulates
            of various nations. But there is a problem, you still cannot recollect 
            anything about yourself. But then you remember about the bag of passports. 
            You checked the bag to find two passports: 
            
            A) British passport under Douglas Quaid 
            B) German passport under Karl Hauser
            
            You look at the photograph embedded within and then check yourself 
            in the mirror and you wonder is this really you...
            
            Which consulate will you enter? 
            
            Type your choice: British or German
            
            """)
    
    #Choice Control Logic - Explained in scene_1
    
    scene4_choice = input(prompt = """> """).upper() # Taking the user I/P
    scene4_answer = []                       # Dummy list to store each word of the I/P
    scene4_answer = scene4_choice.split(" ") # Spliting the user I/P into words
    
    if('BRITISH' in scene4_answer):
        print(f"""
            Enter your the consulate and you scan your passport. You are Douglas
            Quaid. The secretary takes you to a room and locks you in. You turn
            around find your captors waiting for you. Feeling tired, you surrender 
            and take hold you down and inject you with something and you 
            become unconscious.
            
            You wake up only to find yourself back where you started. In the room.
            
            """)
        
        time.sleep(5)
        game_over() # Calling Failure loop 
        
    
    elif('GERMAN' in scene4_answer):
        win_german() # Calling the winning scenario
                   
    else:
        print("Incorrect input! Check your spelling perhaps?\n")
        scene_no = 4 # Passing the scene number to the error loop to return back here
        ask_user(scene_no) #The Error loop
        
# The winning scenario
def win_german(): 
    
    """The following function was defined to control errors and make debugging easier.
    Since the scene was too big to fit under the elif clause, a decision was made to
    code the winning scenario separately.
    
    This function ends with a call to the win() condition"""
    
    # Start of ASCII Art
    passport_german = """ 

        \n      .*******************************************,                            
        \n    .(   German Passport        , G673780         .#          
        \n    .(   ( %/ %.,,* (  # @  , * # *(  # #. .*#    .#                
        \n    .(                                            .#                
        \n    .(   &&&&&&&&&&&&&&&&    &&&&&&&&&&&&&&&&&&   .#                
        \n    .(   &     .##,     %    Name: Karl Hauser    .#                
        \n    .(   &    %    &    %    Born: Stuttgart      .#                
        \n    .(   &     *%&/     %    D.O.B: 05.01.1978    .#                
        \n    .(   &   .&.   &,   %                         .#                
        \n    .(   &  .(      **  %   /%%%%%%%%%%%%%%%%%&/  .#                
        \n    .(   &//////////////%   /(////////////////(/  .#                
        \n     &                                            #,                
        \n     .********************************************,                   

    """ 
    # End of ASCII Art

    print(f"""
    
        You decide to use your German Passport. You enter the consulate and 
        the following conversation ensues...\n

        """)
    
    # Code 346 to 363 is designed to emulate a conversation taking place
    # between two people. With help of time.sleep() function, a momentary
    # pause is induced after each question and answer
    
    # User prompts are used to control the pace of gameplay
    input(prompt = f'Press any key to continue>\n') 
    
    print('\n')
    print("""\n\tSecretary: Willkommen, how can I help you?""")
    time.sleep(1)
    
    print('\n')
    print("""\n\tYou reply instantly: Hallo, ich brauche hilfe!!!""")
    time.sleep(1)
    
    print('\n')
    print("""\nWait what? You speak German! You are confused, but you continue anyways... """)
    time.sleep(1)
    
    print('\n')
    print("""\n\tSecretary: Sure, can I have your passport?""")
    time.sleep(1)
    
    # User prompts are used to control the pace of gameplay
    print('\n')
    input(prompt = 'Press any key to hand her your passport> \n')

    print('\n')
    progress_bar()
    
    print('\n')
    time.sleep(2)
    print(passport_german)
    
    # User prompts are used to control the pace of gameplay
    print('\n')
    time.sleep(1)
    input(prompt = "The scan is complete. <Press any key to continue>\n")

    print('\n')
    print(f"""
        Her face tenses up. She asks you to follow her into a room and she locks
        you in and leaves in a hurry. On the table there is a file. You open it
        and it reads, 

            "Karl Hauser: Lieutant Commander, KSK Special Forces"

        And, under current status, you are listed "missing" since 2019. You continue
        to read your file but, but things start to get hazy...
        
        The whole room starts spinning and things go black and you pass out. 

        """) 
    
    # Waiting for users consent    
    input(prompt = 'Press any key to see what happens next... \n') 
    win_game() # Calling the Winning function


# The winning function
def win_game():
    
    # This is the winning function where the true identity of the character is revealed
    # This function ends by making a call to the good_bye() function that prints a 
    # ASCII field and give users a chance to try again via the ask_user() error loop function
    
    print(f"""
    
        You hear a distant voice, saying "Wake up! Wake up!"
        
        You snap out of it to find your self strapped to a chair, and a guy 
        starring at you. He says "What's up man? Looks like you've had quite
        the ride."
        
        He then hands you a pill, and says it's for the headache. As you walk 
        out of the room, the receptionist says...\n
        
        """)
    
    # Waiting for users consent    
    input(prompt = 'Press any key to hear what she has to say... \n') 
    
    # Letter by letter Logic
    win_game_phrase = "\n\tThank you for playing Total Rekall. We at Rekall make your wildest dreams come true.\n"
    for character in win_game_phrase:
        print(character, end ="")
        time.sleep(0.05)
    
    time.sleep(2)
    
    # Waiting for users consent    
    input(prompt = "Press any key to see if you're still dreaming... \n")
    
    print(f"""
        Perplexed and confused you step out the Rekall and you reach into your 
        pockets to find your identity card. 
        
        You are Douglas Quaid.
        
        {'-' * 80}
        
        You win! Rekall is complete. You made it out!
        
        """)
    time.sleep(6)
    game_over()
    
        
        
        
# The error handling loop
def ask_user(scene_no):
    
    """This is the error handling loop. It gives users 3 chances incase they 
    input an incorrect option. At the end of the third try, the game exit via 
    the bye() function that displays a thank you message and exits the kernal."""
    
    # The try and except clause is used to control error incase the user leaves
    # the user input empty as it is designed to accept some value and cannot be 
    # left blank
    
    try:
    
        # Ask user if they'd like to try again
        check = input(prompt = "Care to try again ? (Y/N): \n").lower().strip()

        # Gives players a maximum of 3 tries
        count = 3
        
        # the while loop checks for the count if 3 incorrect tries has happened
        # the conditional clause helps the error loop to users back to the correct
        # scene in case of an incorrect input
        
        while(count != 0):
            if check[0] == 'y':
                if(scene_no == 1):
                    scene1()
                    count = 3
                    break

                elif(scene_no == 1.2):
                    scene1_2()
                    count = 3
                    break

                elif(scene_no == 2):
                    scene2()
                    count = 3
                    break
                
                elif(scene_no == 3):
                    scene3()
                    count = 3
                    break
                
                elif(scene_no == 4):
                    scene4()
                    count = 3
                    break

            elif check[0] == 'n':
                bye()
                break

            else:
                print(f"Please enter valid inputs. You have {count} tries remaining.")
                check = input(prompt = "Enter Y for yes or N for no: \n").lower().strip()
                count -= 1
                continue
                
    except:
        print("Please type Y for yes or N for no: ")
        check = input(prompt = "> ")
        ask_user(scene_no)
        
    # To exits the game if user has exceeded their 3 tries   
    if(count == 0):
        print(f"{'-' * 80}")
        bye()
    else:
        pass
    
# The goodbye function       
def bye():
    
    # Docstring
    """ This is the fail loop! The game will end and the kernal will be 
        refreshed automatically """
    
    print(f"{'-' * 80}")
    print("Okay, no worries! Thanks for playing!\n")
    exit() #exit the game and refresh the kernel
    
# The failure function
def game_over():
    
    # Docstring
    """ This is a purely cosmetic function designed to print an ASCII field
        saying GAMEOVER and also ask users if they would like to try again."""
    
    print(f"""     
    
{'*' * 80}
   ______                        ____                 
  / ____/___ _____ ___  ___     / __ \_   _____  _____
 / / __/ __ `/ __ `__ \/ _ \   / / / / | / / _ \/ ___/
/ /_/ / /_/ / / / / / /  __/  / /_/ /| |/ /  __/ /    
\____/\__,_/_/ /_/ /_/\___/   \____/ |___/\___/_/     
                                                          
{'*' * 80}

""")
    scene_no = 1
    ask_user(scene_no)

def progress_bar():
    
    # Docstring
    """ This is a purely cosmetic function designed to emulate a progress bar """
    
    bar = '-' * 80
   
    for character in bar:
        print(character, end ="")
        time.sleep(0.05)
    print(" 100%")

        
        
###############################################################################        

# Starting the game 
intro()

input(prompt = '<Press any key to start>') # Waiting for users consent
print("\n Loading Game")
progress_bar() # Displaying a progress bar

time.sleep(1) # Controlling the speed of gameplay

# Initiating the game 
scene1()
